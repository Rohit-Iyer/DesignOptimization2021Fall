# %% [markdown]
#  #                                                  HOMEWORK 4

# %% [markdown]
# ## Problem 1 (10 Points)
# Sketch graphically the problem
#
# $$
# \begin{aligned}
# \min_{x_1,x_2}  \quad f({\bf x})=(x_1+1)^2+(x_2-2)^2\\
# {\text{subject to }}  \quad g_1 = x_1-2\leq 0,{\quad} g_3 = -x_1\leq 0,\\
#  \quad g_2 = x_2-1\leq 0, {\quad} g_4 = -x_2\leq 0.
# \end{aligned}
# $$
# Find the optimum graphically. Determine directions of feasible descent at the corner points of the feasible domain. Show the gradient directions of $f$ and $g_i$s at these points. Verify graphical results analytically using the KKT conditions.

# %% [markdown]
# Sketeching the graph:
#
# ![Q1.jpeg](attachment:Q1.jpeg)

# %% [markdown]
# The optimum solution of the constrained function is located at (0,1) according to the graph.
#
# The gradient directions are shown by $\Delta$f
#
# At (0,0) , (2,0) and (2,1) - Feasiable direction exists
# But at (0,1) - There is no feseabile direction.
#
# ### Verifying using KKT conditions
#
# Forming the lagrangian function:
#
# L(x, μ ) = ($x_1$ + 1)^2 + ($x_2$ - 2)^2 + μ_1 ($x_1$ - 2) + μ_2 ($x_2$ - 1) + μ_3 (-$x_1$) + μ_4 (-$x_2$)
#
# Since point (0,1) is on  $g_2$ and $g_3$, µ_1 = µ_4 = 0
# Also, µ_2, µ_3 > 0

# %% [markdown]
# ![Q1_2.jpeg](attachment:Q1_2.jpeg)
#
#
# The KKT necessary conditions are satisfied at (0,1) and the Hessian is positive definite everywhere.
# Thus, (0,1) is the global minimum as confirmed from the graphical solution

# %% [markdown]
# _________________________________________________________________________________________________________________________

# %% [markdown]
# ## Problem 2 (10 Points)
# Graph the problem
#
# $$
# \begin{aligned}
# \min_{x_1,x_2} \quad  f=-x_1\\
# {\text{subject to }} \quad g_1=x_2-(1-x_1)^3\leq 0{\quad} {\rm and}{\quad} x_2\geq 0.
# \end{aligned}
# $$
# Find the solution graphically. Then apply the optimality conditions. Can you find a solution based on the optimality conditions? Why? (From Kuhn and Tucker, 1951.)

# %% [markdown]
# Sketching the graph:
#
# ![Q2.jpeg](attachment:Q2.jpeg)
#
# From the graph, we find that the optimum solution is (1,0)
#
# ### Verifying using KKT optimality conditions
#
# The Lagrangian function:
#
# L(x, $\mu$ ) =  f(x) + $\mu$g(x) = -$x_1$ + $\mu$_1 ($x_2$ - (1 - $x_1$)^3 + $\mu$_2(-$x_2$)

# %% [markdown]
# ![Q2_2.jpeg](attachment:Q2_2.jpeg)
#
# Here, -1=0 is not possible. Hence, no solution exists because (1,0) is not a regular point as the constraints given are lineraly dependent at that point, i.e., not affine

# %% [markdown]
# _________________________________________________________________________________________________________________________

# %% [markdown]
# ## Problem 3 (30 Points)
# Find a local solution to the problem
#
# $$
# \begin{aligned}
# \max_{x_1,x_2,x_3} \quad  f=x_1x_2+x_2x_3+x_1x_3\\
# {\text{subject to }} \quad h=x_1+x_2+x_3-3=0.
# \end{aligned}
# $$
# Use two methods: reduced gradient and Lagrange multipliers.

# %% [markdown]
# ### Using Reduced gradient
#
# Let $d_1$ = $x_1$, $d_2$ = $x_2$ and $s_1$ = $x_3$ = 6 - $x_1$ - $x_2$
#
# At the optimum case:
# ![Screenshot%20%2822%29.png](attachment:Screenshot%20%2822%29.png)

# %% [markdown]
# Where
# ![Screenshot%20%2822%29%20-%20Copy.png](attachment:Screenshot%20%2822%29%20-%20Copy.png)

# %% [markdown]
# ![Screenshot%20%2821%29.png](attachment:Screenshot%20%2821%29.png)

# %% [markdown]
# ![Screenshot%20%2823%29%20-%20Copy.png](attachment:Screenshot%20%2823%29%20-%20Copy.png)

# %% [markdown]
# ![Screenshot%20%2824%29%20-%20Copy.jpg](attachment:Screenshot%20%2824%29%20-%20Copy.jpg)

# %% [markdown]
# Hence,
#
# ![Screenshot%20%2822%29%20-%20Copy.png](attachment:Screenshot%20%2822%29%20-%20Copy.png)
#
# which is  = 0
#
# Therefore, we have $x_1$ = $x_2$ = $x_3$ = 1
#  And the hessian is Positive definite and = 3
#
# Thus, (1,1,1) is the optimum solution

# %% [markdown]
# ### Using Lagrange Multipliers
#
# Forming equation:
#
# L(x,λ) = −f(x) + λh(x) = −$x_1$ $x_2$ − $x_2$ $x_3$ − $x_3$ $x_1$ + λ($x_1$ + $x_2$ + $x_3$ − 3)
#
# and the gradient
# <br>
# $$\mathbf{L} = \begin{bmatrix} -x_2 - x_3 + λ  \\-x_1 - x_3 + λ \\ -x_1 - x_2 + λ \end{bmatrix}
# $$
# Therefore
# <br>
# $\Delta$L = 0

# %% [markdown]
# On solving the above sets of equation with constraint h, we get
# $x_1$ = $x_2$ = $x_3$ = 1 and λ = 2
#
# Also, the hessian is p.s.d and hence (1,1,1) is the optimal solution

# %% [markdown]
# _________________________________________________________________________________________________________________________

# %% [markdown]
# ## Problem 4 (20 Points)
# Use reduced gradient to find the value(s) of the parameter $b$ for which the point $x_1=1$, $x_2=2$ is the solution to the problem
#
# $$
# \begin{aligned}
# \max_{x_1,x_2}  \quad  f=2x_{1} + bx_2\\
# {\text{subject to }} \quad g_1 = x_{1}^{2}+ x_{2}^{2}-5\leq 0\\
#  \quad g_2= x_1- x_2-2\leq 0.
# \end{aligned}
# $$

# %% [markdown]
# Re-writing the formulation in minimization format
#
# $$
# \begin{aligned}
# \min_{x_1,x_2}  \quad  f = -2x_{1} - bx_2\\
# {\text{subject to }} \quad g_1 = x_{1}^{2}+ x_{2}^{2}-5\leq 0\\
#  \quad g_2= x_1- x_2-2\leq 0.
# \end{aligned}
# $$

# %% [markdown]
# Putting the value of $x_1$ and $x_2$ as (1,2) to check if $g_1$ and $g_2$ are active or not. We get
# $g_1$ = 0
# $g_2$ = -3
#
# Thus, the first inequality constraint is active as $g_1$ = 0 and the second is inactive as it is -3
#
# Let $x_1$ = s and $x_2$ = d
#
# The langrangian is:
#
# ![Screenshot%20%2822%29.png](attachment:Screenshot%20%2822%29.png)
#
#  = −b − (−2)(2)^(−1)(4) = 0
#
# Thus
# b = 4
#
# Also, Hessian (H) = 5 > 0, and hence p.d.
#
# Therefore b = 4 and (1,2) is a local minima.

# %% [markdown]
# _________________________________________________________________________________________________________________________

# %% [markdown]
# ## Problem 5 (30 Points)
# Find the solution for
#
# $$
# \begin{aligned}
# \min_{x_1,x_2,x_3}  \quad  f=x_{1}^{2}+x_{2}^{2}+x_{3}^{2}\\
# {\text{subject to }}  \quad h_1 = x_{1}^{2}/4+x_{2}^{2}/5+x_{3}^{2}/25-1=0\\
# \quad h_2 = x_1+x_2-x_3= 0,
# \end{aligned}
# $$
# by implementing the generalized reduced gradient algorithm.

# %% [markdown]
# Let:
# d = $x_1$ and,
# s = [$x_2$, $x_3$] = [0,0]
# <br>Therefore:
# <br>
# <br>
# $\delta$f/$\delta$d = 2$x_1$
# <br>
# $\delta$f/$\delta$s = $$\begin{bmatrix} 2 x_2 \\ 2 x_3 \end{bmatrix}$$
#
# $\delta$h/$\delta$s = $$\begin{bmatrix} 2 x_2 / 5 & 2 x_3 / 25   \\ 1 & -1 \end{bmatrix}$$
#
# $\delta$h/$\delta$d = $$\begin{bmatrix} x_1 / 2 \\ 1 \end{bmatrix}$$

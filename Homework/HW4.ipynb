# %% [markdown]
#  #                                                  HOMEWORK 4

# %% [markdown]
# ## Problem 1 (10 Points)
# Sketch graphically the problem
#
# $$
# \begin{aligned}
# \min_{x_1,x_2}  \quad f({\bf x})=(x_1+1)^2+(x_2-2)^2\\
# {\text{subject to }}  \quad g_1 = x_1-2\leq 0,{\quad} g_3 = -x_1\leq 0,\\
#  \quad g_2 = x_2-1\leq 0, {\quad} g_4 = -x_2\leq 0.
# \end{aligned}
# $$
# Find the optimum graphically. Determine directions of feasible descent at the corner points of the feasible domain. Show the gradient directions of $f$ and $g_i$s at these points. Verify graphical results analytically using the KKT conditions.

# %% [markdown]
# Sketching the graph:
#
# ![Screenshot%20%2817%29.jpg](attachment:Screenshot%20%2817%29.jpg)

# %% [markdown]
# The optimum solution of the constrained function is located at (0,1) according to the graph.
#
# The gradient directions are shown by $\Delta$f
#
# At (0,0) , (2,0) and (2,1) - Feasiable direction exists
# But at (0,1) - There is no feseabile direction.
#
# ### Verifying using KKT conditions
#
# Forming the lagrangian function:
#
# L(x, $\mu$ ) = ($x_1$ + 1)^2 + ($x_2$ - 2)^2 + $\mu$_1 ($x_1$ - 2) + $\mu$_2 ($x_2$ - 1) + $\mu$_3 (-$x_1$) + $\mu$_4 (-$x_2$)
#
# Since point (0,1) is on  $g_2$ and $g_3$, $µ_1$ = $µ_4$ = 0
# Also, $µ_2$, $µ_3$ > 0
#
# ![Screenshot%20%2818%29.png](attachment:Screenshot%20%2818%29.png)
#
# The KKT necessary conditions are satisfied at (0,1) and the Hessian is positive definite everywhere.
# Thus, (0,1) is the global minimum as confirmed from the graphical solution

# %% [markdown]
# ## Problem 2 (10 Points)
# Graph the problem
#
# $$
# \begin{aligned}
# \min_{x_1,x_2} \quad  f=-x_1\\
# {\text{subject to }} \quad g_1=x_2-(1-x_1)^3\leq 0{\quad} {\rm and}{\quad} x_2\geq 0.
# \end{aligned}
# $$
# Find the solution graphically. Then apply the optimality conditions. Can you find a solution based on the optimality conditions? Why? (From Kuhn and Tucker, 1951.)

# %% [markdown]
# Sketching the graph:
#
# ![Screenshot%20%2819%29.png](attachment:Screenshot%20%2819%29.png)
#
# From the graph, we find that the optimum solution is (1,0)
#
# ### Verifying using KKT optimality conditions
#
# The Lagrangian function:
#
# L(x, $\mu$ ) =  f(x) + $\mu$g(x) = -$x_1$ + $\mu$_1 ($x_2$ - (1 - $x_1$)^3 + $\mu$_2(-$x_2$)

# %% [markdown]
# ![Screenshot%20%2820%29.jpg](attachment:Screenshot%20%2820%29.jpg)
#
# Here, -1=0 is not possible. Hence, no solution exists because (1,0) is not a regular point as the constraints given are lineraly dependent at that point, i.e., not affine

# %% [markdown]
# ## Problem 3 (30 Points)
# Find a local solution to the problem
#
# $$
# \begin{aligned}
# \max_{x_1,x_2,x_3} \quad  f=x_1x_2+x_2x_3+x_1x_3\\
# {\text{subject to }} \quad h=x_1+x_2+x_3-3=0.
# \end{aligned}
# $$
# Use two methods: reduced gradient and Lagrange multipliers.

# %% [markdown]
# ## Problem 4 (20 Points)
# Use reduced gradient to find the value(s) of the parameter $b$ for which the point $x_1=1$, $x_2=2$ is the solution to the problem
#
# $$
# \begin{aligned}
# \max_{x_1,x_2}  \quad  f=2x_{1} + bx_2\\
# {\text{subject to }} \quad g_1 = x_{1}^{2}+ x_{2}^{2}-5\leq 0\\
#  \quad g_2= x_1- x_2-2\leq 0.
# \end{aligned}
# $$

# %% [markdown]
# ## Problem 5 (30 Points)
# Find the solution for
#
# $$
# \begin{aligned}
# \min_{x_1,x_2,x_3}  \quad  f=x_{1}^{2}+x_{2}^{2}+x_{3}^{2}\\
# {\text{subject to }}  \quad h_1 = x_{1}^{2}/4+x_{2}^{2}/5+x_{3}^{2}/25-1=0\\
# \quad h_2 = x_1+x_2-x_3= 0,
# \end{aligned}
# $$
# by implementing the generalized reduced gradient algorithm.
